# %% [markdown]
# # 🧪 Exercise 2
# ### Hands-On with Pandas: A Beginner’s Exercise Notebook for Data Mining
#
# Welcome to your Pandas practice notebook! Pandas is one of the most powerful Python libraries for data analysis and is a cornerstone of modern data mining. In this notebook, you'll work through a series of exercises that will help you understand the structure and capabilities of Pandas, and apply them to real datasets.

# %% [markdown]
# ## 1. Getting Started with Pandas
#
# Pandas provides high-performance, easy-to-use data structures: `Series` (1D) and `DataFrame` (2D). It is particularly useful for cleaning, transforming, and analyzing structured data.
#
# We'll begin by loading a dataset and doing some initial exploration.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ✅ Task for students: Load the Titanic dataset from seaborn into a pandas dataframe named df and display the first few rows
import seaborn as sns
import pandas as pd
#sns.get_dataset_names() #- This will print a list of dataset names you can use

ds= sns.load_dataset('titanic')
df= pd.DataFrame(ds)
display(df)   #print(df) and just df give diff outlooks
display(df.head())
display(df.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df.iloc[:10]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %% [markdown]
# ### Exercise 1.1
# ✅ Tasks for students: configure pandas visualization: You can configure display settings, so your DataFrames look cleaner and are easier to interpret.

# %%
#  Display less columns and rows (10, 10)
import pandas as pd
# dir(pd)

#help(pd.set_option)
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows',10)                   #Set_option - helps modify the code
                                          #describe_option - helps display current setting and default setting
pd.describe_option('display.max_columns')
pd.describe_option('display.max_rows')

# Align column headers nicely
pd.set_option('display.colheader_justify', 'center')

pd.describe_option('display.colheader_justify')
# Set column width to 100 and precision to 2
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.precision', 2)

pd.describe_option('display.max_colwidth')
pd.describe_option('display.precision')
# Set float display precision to 2
pd.set_option('display.float_format', '{:.2}'.format) # ??, help or look up official documentation for syntax of the ''

pd.describe_option('display.float_format')

display(df)
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 or None and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection and defaults to 20.
#     [default: 20] [currently: 10]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 10]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: center]
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 100]
# display.precision : int
#     Floating point output precision in terms of number of places after the
#     decimal, for regular formatting as well as scientific notation. Similar
#     to ``precision`` in :meth:`numpy.set_printoptions`.
#     [default: 6] [currently: 2]
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: <built-in method format of str object at 0x7fe57fcbf730>]
#      survived  pclass   sex      age   sibsp  ...  adult_male  deck  \
# 0        0        3      male 2.2e+01    1    ...      True     NaN
# 1        1        1    female 3.8e+01    1    ...     False       C
# 2        1        3    female 2.6e+01    0    ...     False     NaN
# 3        1        1    female 3.5e+01    1    ...     False       C
# 4        0        3      male 3.5e+01    0    ...      True     NaN
# ..        ...     ...     ...     ...    ...  ...         ...   ...
# 886      0        2      male 2.7e+01    0    ...      True     NaN
# 887      1        1    female 1.9e+01    0    ...     False       B
# 888      0        3    female     NaN    1    ...     False     NaN
# 889      1        1      male 2.6e+01    0    ...      True       C
# 890      0        3      male 3.2e+01    0    ...      True     NaN
#
#     embark_town  alive alone
# 0    Southampton    no  False
# 1      Cherbourg   yes  False
# 2    Southampton   yes   True
# 3    Southampton   yes  False
# 4    Southampton    no   True
# ..           ...   ...    ...
# 886  Southampton    no   True
# 887  Southampton   yes   True
# 888  Southampton    no  False
# 889    Cherbourg   yes   True
# 890   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.colheader_justify')
pd.reset_option('display.max_colwidth')
pd.reset_option('display.precision')
pd.reset_option('display.float_format')

pd.describe_option('display.max_columns')
pd.describe_option('display.max_rows')
pd.describe_option('display.colheader_justify')
pd.describe_option('display.max_colwidth')
pd.describe_option('display.precision')
pd.describe_option('display.float_format')

df.head()
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 or None and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection and defaults to 20.
#     [default: 20] [currently: 20]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 50]
# display.precision : int
#     Floating point output precision in terms of number of places after the
#     decimal, for regular formatting as well as scientific notation. Similar
#     to ``precision`` in :meth:`numpy.set_printoptions`.
#     [default: 6] [currently: 6]
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: None]
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Exercise 1.2
# ✅ Task for students: Inspect the dataset:
# - Use `.info()` to understand the structure
# - Use `.describe()` to get summary statistics
# - Count the number of missing values per column

# %%
df.info()   # total enteries - non-null per column
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()  # Count the number of missing values per column
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## 2. Pandas Objects: Series and DataFrames
#
# Everything in Pandas is built around `Series` and `DataFrame` objects. A `Series` is like a column in a spreadsheet, and a `DataFrame` is like the full table.

# %% [markdown]
# ### Exercise 2.1
# Create a `Series` and a `DataFrame` manually.

# %%
# ✅ Task for students: Create a Series containing [10, 20, 30] as values and ['a', 'b', 'c'] as indices and print it
import pandas as pd

#help(pd.Series)
pd.Series([10, 20, 30], index =['a', 'b', 'c'])
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# ✅ Task for students: Create a DataFrame containing a dictionary with  names, ages, and cities of three imaginary people and print it
pd.DataFrame({'Name': ['Ram', 'sow','Bika'], 'Age':[22,23,5], 'City':['Bangalore','Chennai','Frankfurt']})
# Out:
#    Name  Age       City
# 0   Ram   22  Bangalore
# 1   sow   23    Chennai
# 2  Bika    5  Frankfurt

# %% [markdown]
# ### Exercise 2.2
# ✅ Task for students: Explore the components:
# - `values`
# - `index`
# - `columns`

# %%
#pd.DataFrame??
df.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
df.index  #index value starts at 0, stops at 891 and is incremented by 1
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ## 3. Indexing and Selection
#
# Selecting and filtering data is one of the most common tasks in data mining. Pandas provides powerful indexing options using `.loc`, `.iloc`, slicing, and Boolean masks.
#
# ![image.png](attachment:2870e45c-540f-406c-b615-856e2988de2a.png)

# %%
# ✅ Task for students: Use .loc (label-based) to print first or second row
print(df.loc[0])
print('*****************************')
print(df.loc[1])
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
# *****************************
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
# the loc works with any values used in the index regardless of the type
df.index = [f"row_{i+1}" for i in range(len(df))] #this line replaces the DataFrame’s index (row labels) with a list of custom strings:like 0---> row_1
df.loc["row_2"]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: row_2, dtype: object

# %%
# ✅ Task for students: Use .iloc (integer position-based) to print the first of the fifth row
df.iloc[5,0]
# Out:
# 0

# %% [markdown]
# ### Exercise 3.1
#
# selection and selective printing

# %%
# ✅ Task for students: Select the first 5 rows where passengers are female
#df[df['column_name'] == value].head(N)   #boolean indexing

df[df['sex'] == 'female'].head(5)
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# row_2          1       1  female  38.0      1      0  71.2833        C
# row_3          1       3  female  26.0      0      0   7.9250        S
# row_4          1       1  female  35.0      1      0  53.1000        S
# row_9          1       3  female  27.0      0      2  11.1333        S
# row_10         1       2  female  14.0      1      0  30.0708        C
#
#          class    who  adult_male deck  embark_town alive  alone
# row_2    First  woman       False    C    Cherbourg   yes  False
# row_3    Third  woman       False  NaN  Southampton   yes   True
# row_4    First  woman       False    C  Southampton   yes  False
# row_9    Third  woman       False  NaN  Southampton   yes  False
# row_10  Second  child       False  NaN    Cherbourg   yes  False

# %%
#With loc
df.loc[df["sex"] == "female"].head(5) #Label-based, accepts boolean indexing
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# row_2          1       1  female  38.0      1      0  71.2833        C
# row_3          1       3  female  26.0      0      0   7.9250        S
# row_4          1       1  female  35.0      1      0  53.1000        S
# row_9          1       3  female  27.0      0      2  11.1333        S
# row_10         1       2  female  14.0      1      0  30.0708        C
#
#          class    who  adult_male deck  embark_town alive  alone
# row_2    First  woman       False    C    Cherbourg   yes  False
# row_3    Third  woman       False  NaN  Southampton   yes   True
# row_4    First  woman       False    C  Southampton   yes  False
# row_9    Third  woman       False  NaN  Southampton   yes  False
# row_10  Second  child       False  NaN    Cherbourg   yes  False

# %%
# with iloc for the first 5
df[df["sex"] == "female"].iloc[:5] #Position-based after filtering
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# row_2          1       1  female  38.0      1      0  71.2833        C
# row_3          1       3  female  26.0      0      0   7.9250        S
# row_4          1       1  female  35.0      1      0  53.1000        S
# row_9          1       3  female  27.0      0      2  11.1333        S
# row_10         1       2  female  14.0      1      0  30.0708        C
#
#          class    who  adult_male deck  embark_town alive  alone
# row_2    First  woman       False    C    Cherbourg   yes  False
# row_3    Third  woman       False  NaN  Southampton   yes   True
# row_4    First  woman       False    C  Southampton   yes  False
# row_9    Third  woman       False  NaN  Southampton   yes  False
# row_10  Second  child       False  NaN    Cherbourg   yes  False

# %%
# ✅ Task for students: Select all passengers under the age of 18
'Using loc'
a= df.loc[df['age'] < 18]
display(a)
# Out:
#          survived  pclass     sex   age  sibsp  parch     fare embarked  \
# row_8           0       3    male   2.0      3      1  21.0750        S
# row_10          1       2  female  14.0      1      0  30.0708        C
# row_11          1       3  female   4.0      1      1  16.7000        S
# row_15          0       3  female  14.0      0      0   7.8542        S
# row_17          0       3    male   2.0      4      1  29.1250        Q
# ...           ...     ...     ...   ...    ...    ...      ...      ...
# row_851         0       3    male   4.0      4      2  31.2750        S
# row_853         0       3  female   9.0      1      1  15.2458        C
# row_854         1       1  female  16.0      0      1  39.4000        S
# row_870         1       3    male   4.0      1      1  11.1333        S
# row_876         1       3  female  15.0      0      0   7.2250        C
#
#           class    who  adult_male deck  embark_town alive  alone
# row_8     Third  child       False  NaN  Southampton    no  False
# row_10   Second  child       False  NaN    Cherbourg   yes  False
# row_11    Third  child       False    G  Southampton   yes  False
# row_15    Third  child       False  NaN  Southampton    no   True
# row_17    Third  child       False  NaN   Queenstown    no  False
# ...         ...    ...         ...  ...          ...   ...    ...
# row_851   Third  child       False  NaN  Southampton    no  False
# row_853   Third  child       False  NaN    Cherbourg    no  False
# row_854   First  woman       False    D  Southampton   yes  False
# row_870   Third  child       False  NaN  Southampton   yes  False
# row_876   Third  child       False  NaN    Cherbourg   yes   True
#
# [113 rows x 15 columns]

# %%
# ✅ Task for students: Select all passengers under the age of 18
from termcolor import colored
'Using iloc'
a= df.loc[df['age'] < 18]
b = df[df['age'] < 18].iloc[:]
display(b)

if a.equals(b):
    print(colored('Both iloc and loc give the same output', 'red'))
# Out:
#          survived  pclass     sex   age  sibsp  parch     fare embarked  \
# row_8           0       3    male   2.0      3      1  21.0750        S
# row_10          1       2  female  14.0      1      0  30.0708        C
# row_11          1       3  female   4.0      1      1  16.7000        S
# row_15          0       3  female  14.0      0      0   7.8542        S
# row_17          0       3    male   2.0      4      1  29.1250        Q
# ...           ...     ...     ...   ...    ...    ...      ...      ...
# row_851         0       3    male   4.0      4      2  31.2750        S
# row_853         0       3  female   9.0      1      1  15.2458        C
# row_854         1       1  female  16.0      0      1  39.4000        S
# row_870         1       3    male   4.0      1      1  11.1333        S
# row_876         1       3  female  15.0      0      0   7.2250        C
#
#           class    who  adult_male deck  embark_town alive  alone
# row_8     Third  child       False  NaN  Southampton    no  False
# row_10   Second  child       False  NaN    Cherbourg   yes  False
# row_11    Third  child       False    G  Southampton   yes  False
# row_15    Third  child       False  NaN  Southampton    no   True
# row_17    Third  child       False  NaN   Queenstown    no  False
# ...         ...    ...         ...  ...          ...   ...    ...
# row_851   Third  child       False  NaN  Southampton    no  False
# row_853   Third  child       False  NaN    Cherbourg    no  False
# row_854   First  woman       False    D  Southampton   yes  False
# row_870   Third  child       False  NaN  Southampton   yes  False
# row_876   Third  child       False  NaN    Cherbourg   yes   True
#
# [113 rows x 15 columns]
# Both iloc and loc give the same output

# %% [markdown]
# ## 4. Operations in Pandas
#
# Pandas allows you to perform element-wise and column-wise operations efficiently. These include arithmetic operations, aggregations, and applying custom functions.

# %%
# ✅ Task for students: calculate mean age per gender and class
df[df['sex'] == 'female']['age'].mean()
# Out:
# 27.915708812260537

# %% [markdown]
# ###  Exercise 4.1

# %%
# ✅ Task for students: add a column for fare per age
df['fare_per_age'] = df['fare'] / df['age']
df[['fare', 'age', 'fare_per_age']].head()
# Out:
#           fare   age  fare_per_age
# row_1   7.2500  22.0      0.329545
# row_2  71.2833  38.0      1.875876
# row_3   7.9250  26.0      0.304808
# row_4  53.1000  35.0      1.517143
# row_5   8.0500  35.0      0.230000

# %%
# ✅ Task for students: Use `.mean()` and `.median()` to summarize it
print('Mean fare per age ', df[[ 'fare_per_age']].mean())
print('Median fare per age',(df[[ 'fare_per_age']].median()))
# Out:
# Mean fare per age  fare_per_age    2.391841
# dtype: float64
# Median fare per age fare_per_age    0.565217
# dtype: float64

# %% [markdown]
# ##  ✅ 5. Task for students: Mini Data Mining Project: Exploring Titanic Data
#
# Now it's your turn to apply what you've learned to gain insights from the Titanic dataset.
#
# ###  Questions:
# 1. What’s the average fare paid by survivors vs non-survivors? try plotting it in a pie chart.
# 2. Who had a higher survival rate: children (<16) or adults?
# 4. What’s the most common port of embarkation?
# 5. Clean the data (e.g., fill or drop missing values in 'age' or 'embarked')
# 6. Use `groupby`, `value_counts`, and filtering to answer the questions
# 7. Try plotting with seaborn (e.g., `sns.histplot`, `sns.barplot`) and with `pandas.DataFrame.plot.pie`

# %%
# print the average fare paid by survivors vs non-survivors using a pie chart
print ("Avg Fare Paid by Survivors : " , df.loc[df.survived == 1]['fare'].mean()) 
print ("Avg Fare Paid by Non-Survivors : " , df.loc[df.survived == 0]['fare'].mean())
# Out:
# Avg Fare Paid by Survivors :  48.39540760233918
# Avg Fare Paid by Non-Survivors :  22.117886885245902

# %%
# Create a new column for age group
import numpy as np

def tell_age(x):
    if x <= 12:
        return 'Child'
    elif x <= 17 :
        return 'Teen'
    else:
        return 'Adult'

df['age_group']=df['age'].apply(tell_age)
#df.loc[df.age_group == 'Adult']
# Calculate survival rate per group
df.groupby('age_group')['survived'].mean()    #df.groupby(['col1', 'col2'])
                                              #df.groupby('column_name')['value_column'].mean()
# Out:
# age_group
# Adult    0.361183
# Child    0.579710
# Teen     0.477273
# Name: survived, dtype: float64

# %%
# find and print the most common port of embarkation
print(df.embark_town.value_counts().idxmax())
#or
most_common_port = df.embark_town.value_counts().idxmax()
count = df.embark_town.value_counts().max()
print(f"Most common port: {most_common_port} ({count} passengers)")
# Out:
# Southampton
# Most common port: Southampton (644 passengers)

# %%
# clean the data (e.g., fill or drop missing values in 'age' or 'embarked')
Droped = df.dropna(subset = ['age','embarked'])
#Droped[Droped['age'].isnull()] or (returns Empty Dataframe)
#Droped['age'].isnull().sum() (Returns 0)
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone, fare_per_age, age_group]
# Index: []

# %%
# find and print survival rate for children (<16) and adults

# Filter the DataFrame for children and adults
children = df[df['age'] < 16]
adults = df[df['age'] >= 16]

# Calculate survival rates
children_survival_rate = children['survived'].mean()
adults_survival_rate = adults['survived'].mean()

print("Children survival rate:", children_survival_rate)
print("Adults survival rate:", adults_survival_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # find and print survival rate for children (<16) and adults
#       2
#       3 # Filter the DataFrame for children and adults
# ----> 4 children = df[df['age'] < 16]
#       5 adults = df[df['age'] >= 16]
#       7 # Calculate survival rates
#
# NameError: name 'df' is not defined
